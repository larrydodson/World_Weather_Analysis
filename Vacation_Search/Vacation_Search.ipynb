# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("WeatherPy_database.csv")
city_data_df.head(10)
# Out:
#    City_ID             City Country    Lat     Lng  Max Temp  Humidity  \
# 0        0     Punta Arenas      CL -53.15  -70.92     44.60        75
# 1        1         Klaksvik      FO  62.23   -6.59     51.80        93
# 2        2           Xuddur      SO   4.12   43.89     73.44        65
# 3        3          Ushuaia      AR -54.80  -68.30     39.20        86
# 4        4           Mocuba      MZ -16.84   36.99     63.16        74
# 5        5  Bourg-En-Bresse      FR  46.17    5.17     64.00        68
# 6        6       Butaritari      KI   3.07  172.79     82.81        66
# 7        7            Airai      TL  -8.93  125.41     58.55        69
# 8        8         Goderich      CA  43.75  -81.72     81.00        66
# 9        9           Castro      BR -24.79  -50.01     67.77        70
#
#    Cloudiness  Wind Speed      Current Description
# 0          40        9.17         scattered clouds
# 1          59       16.11               light rain
# ...

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria in °F.
min_temp = float(input("What is the minimum temperature in °F you would like for your trip? "))
max_temp = float(input("What is the maximum temperature in °F you would like for your trip? "))
# Out:
# What is the minimum temperature in °F you would like for your trip? 74
# What is the maximum temperature in °F you would like for your trip? 89

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df
# Out:
#      City_ID              City Country    Lat     Lng  Max Temp  Humidity  \
# 6          6        Butaritari      KI   3.07  172.79     82.81        66
# 8          8          Goderich      CA  43.75  -81.72     81.00        66
# 12        12    Ribeira Grande      PT  38.52  -28.70     75.20        73
# 18        18      Puerto Ayora      EC  -0.74  -90.35     75.20        60
# 23        23             Yalta      UA  44.50   34.17     75.43        68
# ..       ...               ...     ...    ...     ...       ...       ...
# 688      688  Puerto Escondido      MX  15.85  -97.07     87.80        58
# 691      691              Muli      MV   2.92   73.57     82.58        78
# 692      692             Manta      EC  -0.95  -80.73     77.00        78
# 699      699           Durango      MX  24.83 -104.83     75.60        48
# 701      701            Olinda      BR  -8.01  -34.86     78.80        69
#
#      Cloudiness  Wind Speed Current Description
# ...

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                242
# City                   242
# Country                242
# Lat                    242
# Lng                    242
# Max Temp               242
# Humidity               242
# Cloudiness             242
# Wind Speed             242
# Current Description    242
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
# Determine if there are not any missing values in the data.
preferred_cities_df.notnull().sum()
# Out:
# City_ID                242
# City                   242
# Country                242
# Lat                    242
# Lng                    242
# Max Temp               242
# Humidity               242
# Cloudiness             242
# Wind Speed             242
# Current Description    242
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 6       Butaritari      KI     82.81          few clouds   3.07  172.79
# 8         Goderich      CA     81.00    scattered clouds  43.75  -81.72
# 12  Ribeira Grande      PT     75.20    scattered clouds  38.52  -28.70
# 18    Puerto Ayora      EC     75.20          few clouds  -0.74  -90.35
# 23           Yalta      UA     75.43          few clouds  44.50   34.17
# 26          Bethel      US     81.00           clear sky  41.37  -73.41
# 30        Victoria      HK     84.00       broken clouds  22.29  114.16
# 33       Sinnamary      GF     81.88           clear sky   5.38  -52.95
# 34           Locri      IT     75.99    scattered clouds  38.24   16.26
# 35        Lufilufi      WS     87.80       broken clouds -13.87 -171.60
#
#    Hotel Name
# 6
# 8
# 12
# 18
# 23
# 26
# 30
# 33
# 34
# 35

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    # params[]
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    # base_url = "https://maps.googleapis.com/maps/api/directions/nearbysearch/json"
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df
# Out:
#                  City Country  Max Temp Current Description    Lat     Lng  \
# 6          Butaritari      KI     82.81          few clouds   3.07  172.79
# 8            Goderich      CA     81.00    scattered clouds  43.75  -81.72
# 12     Ribeira Grande      PT     75.20    scattered clouds  38.52  -28.70
# 18       Puerto Ayora      EC     75.20          few clouds  -0.74  -90.35
# 23              Yalta      UA     75.43          few clouds  44.50   34.17
# ..                ...     ...       ...                 ...    ...     ...
# 688  Puerto Escondido      MX     87.80       broken clouds  15.85  -97.07
# 691              Muli      MV     82.58    scattered clouds   2.92   73.57
# 692             Manta      EC     77.00          few clouds  -0.95  -80.73
# 699           Durango      MX     75.60     overcast clouds  24.83 -104.83
# 701            Olinda      BR     78.80    scattered clouds  -8.01  -34.86
#
#                         Hotel Name
# ...

# %%
# Determine if there are any missing values in the data.
hotel_df.isnull().sum()
# Out:
# City                   0
# Country                0
# Max Temp               0
# Current Description    0
# Lat                    0
# Lng                    0
# Hotel Name             0
# dtype: int64

# %%
# Determine if there are not any missing values in the data.
hotel_df.notnull().sum()
# Out:
# City                   242
# Country                242
# Max Temp               242
# Current Description    242
# Lat                    242
# Lng                    242
# Hotel Name             242
# dtype: int64

# %%
# Determine data types for the hotel_df.
# hotel_df.dtypes

# %%
# Put the hotel names in a list.
hotel_names = hotel_df["Hotel Name"].tolist()
# hotel_names
len(hotel_names)
# Out:
# 242

# %%
# 7a. Drop the rows where there is no Hotel Name.

# Create new list of hotels for a loop to iterate.
hotels_to_keep =[]

#hotel_df["Hotel Name"] = ""
for hotel in hotel_names:
    if len(hotel.split()) >= 1:
        hotels_to_keep.append(hotel)

# Get the length of the hotel names that are greater than or equal to 1.
# as the target number of hotels. 
len(hotels_to_keep)
# Out:
# 223

# %%
# 7b. Drop the rows where there is no Hotel Name.
#    replace empty Hotel Name with NaN, then drop the rows with nan. 

hotel_df = hotel_df.replace({'Hotel Name':{'':np.nan}}).dropna(subset=['Hotel Name'])

hotel_df.tail(12)
# Out:
#                  City Country  Max Temp   Current Description    Lat     Lng  \
# 655             Anjar      IN     82.08       overcast clouds  23.13   70.02
# 656              Ipua      BR     81.57         broken clouds -20.44  -48.01
# 667            Trairi      BR     78.60            few clouds  -3.28  -39.27
# 670               Gat      IL     84.99             clear sky  31.61   34.76
# 674       Pundaguitan      PH     82.87         broken clouds   6.37  126.17
# 676     Mbanza-Ngungu      CD     75.87      scattered clouds  -5.25   14.87
# 677            Shingu      JP     76.21  heavy intensity rain  33.73  135.98
# 681         Mahajanga      MG     77.00            few clouds -15.72   46.32
# 688  Puerto Escondido      MX     87.80         broken clouds  15.85  -97.07
# 691              Muli      MV     82.58      scattered clouds   2.92   73.57
# 692             Manta      EC     77.00            few clouds  -0.95  -80.73
# ...

# %%
hotel_df.count()
# Out:
# City                   223
# Country                223
# Max Temp               223
# Current Description    223
# Lat                    223
# Lng                    223
# Hotel Name             223
# dtype: int64

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
#             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
#fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
